# %% [markdown]
# <a href="https://colab.research.google.com/github/hug627/streamlit-for-30-days/blob/main/usa_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-95e9ae6f-d83f-4bb5-a8a5-94c15d0e95f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95e9ae6f-d83f-4bb5-a8a5-94c15d0e95f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# load a dataset in the excel from your comp
# %pip install pandas openpyxl xlrd

# %%
import pandas as pd
housing = pd.read_excel('USA_Housing(1).xlsx', engine='openpyxl')
housing
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
# to check if there are null values
housing.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
x = housing[["Avg. Area Income"]]
y = housing[["Price"]]
x
y
# Out:
#              Price
# 0     1.059034e+06
# 1     1.505891e+06
# 2     1.058988e+06
# 3     1.260617e+06
# 4     6.309435e+05
# ...            ...
# 4995  1.060194e+06
# 4996  1.482618e+06
# 4997  1.030730e+06
# 4998  1.198657e+06
# 4999  1.298950e+06
#
# [5000 rows x 1 columns]

# %%
# splitting the data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=142)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
X_train
# Out:
#       Avg. Area Income
# 3141      40748.653087
# 167       84474.160056
# 4814      82389.522278
# 1296      67026.440485
# 516       76008.080242
# ...                ...
# 443       61538.907787
# 2187      70763.423597
# 1616      75361.237574
# 4607      86985.764343
# 277       57233.608492
#
# [4000 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[21.04970968]])

# %%
lr.intercept_
# Out:
# array([-211166.88874162])

# %%
# predictions
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[1009135.6362518 ],
#        [ 990661.68559344],
#        [1325917.69781878],
#        [1235694.09632215],
#        [1285578.8550281 ],
#        [1191645.13097937],
#        [ 953027.54069187],
#        [ 990441.07479629],
#        [1369471.70581565],
#        [1385782.69410572],
#        [1318308.33453354],
#        [1237633.16243721],
#        [1105735.80610924],
#        [1389132.38136425],
#        [1075702.67151817],
#        [1250523.75050432],
#        [1091969.97793275],
#        [1406465.17470811],
#        [1382436.7567133 ],
#        [ 850628.17497312],
#        [ 971504.37940119],
#        [1365661.05810729],
#        [1388806.74634497],
#        [1219800.55879741],
#        [1453121.7398033 ],
#        [1313156.84647781],
#        [1592453.4029645 ],
#        [1254153.87323655],
#        [1205373.69134099],
#        [1268823.60726885],
#        [ 994540.77005837],
#        [1632706.98589205],
#        [1345055.8282345 ],
#        [1353354.55964309],
# ...

# %%
y_test
# Out:
#              Price
# 1894  8.806823e+05
# 4196  1.079409e+06
# 3690  1.270543e+06
# 3330  1.521141e+06
# 2633  1.640186e+06
# ...            ...
# 1487  1.700110e+06
# 136   1.172386e+06
# 481   1.671669e+06
# 462   1.208665e+06
# 3068  1.057126e+06
#
# [1000 rows x 1 columns]

# %%
from sklearn.metrics import mean_absolute_error,  mean_squared_error,root_mean_squared_error

# %%
# mean squared error
mean_squared_error(y_test,y_pred)
# Out:
# 72589892496.504

# %%
# mean absolute error
mean_absolute_error(y_test,y_pred)
# Out:
# 218372.91843221974

# %%
# root mean squared error
root_mean_squared_error(y_test,y_pred)
# Out:
# 269425.11482136184
