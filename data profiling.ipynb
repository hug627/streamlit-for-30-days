# %% [markdown]
# <a href="https://colab.research.google.com/github/hug627/streamlit-for-30-days/blob/main/data%20profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

# %%
# loading of the dataset
file_id = '1m7005DlhJE3xe42sy8nMV2Xop2GXw3tF'
download_url = f'https://drive.google.com/uc?export=download&id={file_id}'
diabetes = pd.read_csv(download_url)

# %%
# General Information:
# Display the dataset's structure, including column names, data types, and memory usage.
diabetes.info()
# Identify the number of missing values or zeros in the dataset.
print("Missing values:")
print(diabetes.isnull().sum())
print("\nZero values:")
print((diabetes == 0).sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# Missing values:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# ...

# %%
# describe anaylsis
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Look for irregularities, such as columns with unrealistic minimum or maximum values.
# Check for impossible/unrealistic values
print("Columns with zero values (potentially unrealistic):")
print((diabetes == 0).sum())
# Check for extreme values
print("\nPotential irregularities:")
print(f"Glucose = 0: {(diabetes['Glucose'] == 0).sum()} cases")
print(f"BloodPressure = 0: {(diabetes['BloodPressure'] == 0).sum()} cases")
print(f"BMI = 0: {(diabetes['BMI'] == 0).sum()} cases")
print(f"Age < 18: {(diabetes['Age'] < 18).sum()} cases")
print(f"Pregnancies > 15: {(diabetes['Pregnancies'] > 15).sum()} cases")
# Out:
# Columns with zero values (potentially unrealistic):
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64
#
# Potential irregularities:
# Glucose = 0: 5 cases
# BloodPressure = 0: 35 cases
# BMI = 0: 11 cases
# Age < 18: 0 cases
# Pregnancies > 15: 1 cases

# %%
# %pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport

# %%
# Create comprehensive profile report
profile = ProfileReport(
    diabetes,
    title="Diabetes Dataset Analysis Report",
    explorative=True
)
# profile.to_widgets() # This causes issues in Colab
profile.to_file("diabetes_profiling_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Identify missing values in key columns such as Glucose, Insulin, and BMI
missing_values = diabetes[['Glucose', 'Insulin', 'BMI']].isnull().sum()
print("Missing values in key columns:")
print(missing_values)
# Out:
# Missing values in key columns:
# Glucose    0
# Insulin    0
# BMI        0
# dtype: int64

# %%
# Examine correlations between columns like Age, Glucose, and Outcome.
columns_of_interest = ['Age', 'Glucose', 'Outcome']
correlation_matrix = diabetes[columns_of_interest].corr()
print(correlation_matrix)
# Out:
#               Age   Glucose   Outcome
# Age      1.000000  0.263514  0.238356
# Glucose  0.263514  1.000000  0.466581
# Outcome  0.238356  0.466581  1.000000

# %%
# Note any interesting insights or patterns (e.g., higher glucose levels correlated with diabetes diagnosis).
correlations_with_outcome = diabetes.corr()['Outcome'].sort_values(key=abs, ascending=False)
print("Variables most correlated with Diabetes Outcome:")
print(correlations_with_outcome)

# Identify strong correlations (>0.3 or <-0.3)
strong_correlations = correlations_with_outcome[abs(correlations_with_outcome) > 0.3]
print(f"\nStrong correlations with Outcome (>0.3):")
print(strong_correlations)
# Out:
# Variables most correlated with Diabetes Outcome:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# Name: Outcome, dtype: float64
#
# Strong correlations with Outcome (>0.3):
# Outcome    1.000000
# Glucose    0.466581
# Name: Outcome, dtype: float64

# %%
# Write a summary of key observations from both Pandas and the ydata-profiling report.
# To provide you with a meaningful summary, I would need:
# 1.The dataset or CSV files you've analyzed
# 2.The ydata-profiling report (either the HTML file or key outputs)
# 3.Any Pandas analysis results you've generated (summary statistics, data exploration findings, etc.)

# %%
#Mention:Patterns or trends in glucose, BMI, or pregnancies, Any notable correlations between variables, Issues such as missing or zero values in critical columns.


# Glucose patterns:

# Distribution and range of glucose values
# Potential outliers or abnormal readings
# Relationship with diabetes outcomes

# BMI trends:

#Distribution across different categories (underweight, normal, overweight, obese)
#Correlation with other health metrics

#Pregnancy patterns:

#Distribution of pregnancy counts
#Impact on other health variables

#Data quality issues:

#Zero values that might indicate missing data (especially in glucose, BMI, blood pressure, etc.)
#Actually missing values (NaN/null)
#Implausible values
